# %% [markdown]
# ## Perform the following operation on Automog.csv of XYZ custom cars company using pandas

# %%
#Importing the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read data from an existing file

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\Python\\auto-mpg.csv")
df.head
# Out:
# <bound method NDFrame.head of       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model_year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Engineers at XYZ custom cars want to know how many cars are Fuel efficient.

# %% [markdown]
# ## MPG > 29, Horsepower < 93.5, Weight < 2500

# %%
df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0          70    2074          19.5
# 52   30.0          4          88.0          76    2065          14.5
# 53   31.0          4          71.0          65    1773          19.0
# 54   35.0          4          72.0          69    1613          18.0
# 129  31.0          4          79.0          67    1950          19.0
# ..    ...        ...           ...         ...     ...           ...
# 384  32.0          4          91.0          67    1965          15.7
# 385  38.0          4          91.0          67    1995          16.2
# 391  36.0          4         135.0          84    2370          13.0
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
#
#      model year  origin             car name
# 51           71       2          peugeot 304
# 52           71       2            fiat 124b
# ...

# %% [markdown]
# ## Engineers at XYZ custom cars want to know how many cars are Muscle cars.

# %% [markdown]
# ## Displacement>262, Horsepower>126, Weight in range[2800 - 3600]

# %%
df.loc[(df['displacement'] > 262) & (df['horsepower'] > 126) & (df['weight'] >=2800) & (df['weight'] <=3600)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# 10   15.0          8         383.0         170    3563          10.0
# 13   14.0          8         455.0         225    3086          10.0
# 121  15.0          8         318.0         150    3399          11.0
# 166  13.0          8         302.0         129    3169          12.0
# 251  20.2          8         302.0         139    3570          12.8
# 262  19.2          8         305.0         145    3425          13.2
# 264  18.1          8         302.0         139    3205          11.2
#
#      model year  origin                      car name
# 0            70       1     chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Engineers at XYZ custom cars want to know how many cars are SUVs.

# %% [markdown]
# ## Horsepower>140 , Weight>4500

# %%
df.loc[(df['horsepower'] > 140) & (df['weight'] >=4500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 25   10.0          8         360.0         215    4615          14.0
# 28    9.0          8         304.0         193    4732          18.5
# 42   12.0          8         383.0         180    4955          11.5
# 43   13.0          8         400.0         170    4746          12.0
# 44   13.0          8         400.0         175    5140          12.0
# 67   11.0          8         429.0         208    4633          11.0
# 68   13.0          8         350.0         155    4502          13.5
# 90   12.0          8         429.0         198    4952          11.5
# 94   13.0          8         440.0         215    4735          11.0
# 95   12.0          8         455.0         225    4951          11.0
# 103  11.0          8         400.0         150    4997          14.0
# 104  12.0          8         400.0         167    4906          12.5
# 105  13.0          8         360.0         170    4654          13.0
# ...

# %% [markdown]
# ## Engineers at XYZ custom cars want to how many cars are Racecars.

# %% [markdown]
# ## Weight < 2223 , acceleration > 17

# %%
df.loc[(df['acceleration'] > 17) & (df['weight'] < 2223)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19   26.0          4          97.0          46    1835          20.5
# 32   25.0          4          98.0          90    2046          19.0
# 51   30.0          4          79.0          70    2074          19.5
# 53   31.0          4          71.0          65    1773          19.0
# 54   35.0          4          72.0          69    1613          18.0
# 55   27.0          4          97.0          60    1834          19.0
# 56   26.0          4          91.0          70    1955          20.5
# 79   26.0          4          96.0          69    2189          18.0
# 102  26.0          4          97.0          46    1950          21.0
# 117  29.0          4          68.0          49    1867          19.5
# 129  31.0          4          79.0          67    1950          19.0
# 131  32.0          4          71.0          65    1836          21.0
# 145  32.0          4          83.0          61    2003          19.0
# ...

# %% [markdown]
# ## XYZ custom cars want the data sorted according to the number of cylinders.

# %%
df.sort_values(by = 'cylinders')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0          90    2124          13.5
# 71   19.0          3          70.0          97    2330          13.5
# 334  23.7          3          70.0         100    2420          12.5
# 243  21.5          3          80.0         110    2720          13.5
# 267  27.5          4         134.0          95    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0         150    3672          11.5
# 285  17.0          8         305.0         130    3840          15.4
# 286  17.6          8         302.0         129    3725          13.4
# 92   13.0          8         351.0         158    4363          13.0
# 0    18.0          8         307.0         130    3504          12.0
#
#      model year  origin                   car name
# 111          73       3                  maxda rx3
# ...

# %% [markdown]
# ## There is a requirement in which the cars that have lowest acceleration must be assessed.It is also to be checked that whics cars have higher horsepower despite having lower acceleration.

# %%
df.sort_values(['acceleration','horsepower'], ascending = (1,0))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0         160    3609           8.0
# 7    14.0          8         440.0         215    4312           8.5
# 9    15.0          8         390.0         190    3850           8.5
# 6    14.0          8         454.0         220    4354           9.0
# 116  16.0          8         400.0         230    4278           9.5
# ..    ...        ...           ...         ...     ...           ...
# 195  29.0          4          85.0          52    2035          22.2
# 59   23.0          4          97.0          54    2254          23.5
# 326  43.4          4          90.0          48    2335          23.7
# 394  44.0          4          97.0          52    2130          24.6
# 299  27.2          4         141.0          71    3190          24.8
#
#      model year  origin            car name
# 11           70       1  plymouth 'cuda 340
# 7            70       1   plymouth fury iii
# ...

# %% [markdown]
# ## The board of XYZ custom cars wants to know about minimum and maximum sum, mean and median of all the numerical columns

# %%
#Using List comprehension to get the numerical columns
list1 = [col for col in df.columns if df[col].dtype in ['float' , 'int64']]
df[list1].agg(['min' , 'max' , 'sum' , 'mean' , 'median'])
# Out:
#                 mpg    cylinders  displacement    horsepower        weight  \
# min        9.000000     3.000000     68.000000     46.000000  1.613000e+03
# max       46.600000     8.000000    455.000000    230.000000  5.140000e+03
# sum     9358.800000  2171.000000  76983.500000  41484.000000  1.182229e+06
# mean      23.514573     5.454774    193.425879    104.231156  2.970425e+03
# median    23.000000     4.000000    148.500000     92.500000  2.803500e+03
#
#         acceleration   model year      origin
# min          8.00000     70.00000    1.000000
# max         24.80000     82.00000    3.000000
# sum       6196.10000  30252.00000  626.000000
# mean        15.56809     76.01005    1.572864
# median      15.50000     76.00000    1.000000

# %% [markdown]
# ## XYZ custom cars want to know the number of cars manufactured in each year.

# %%
df.groupby(['model_year']).count()['horsepower'] #All values will be same, so display any one column
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: horsepower, dtype: int64

# %% [markdown]
# ## The engineers at XYZ custom cars want to know about the relationship between model year and acceleration of cars.

# %%
df.groupby(['model_year']).mean()[['acceleration']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %% [markdown]
# ## The engineers at XYZ custom cars wants to know the frequency distribution of different number of cylinders across different years.

# %%
pd.crosstab(df['model_year'], df['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0

# %% [markdown]
# ## The engineers at XYZ custon cars want to know the mean of all the numerical attributes of cars for each year

# %%
pivot1 = pd.pivot_table(df, index = 'model_year' , aggfunc=np.mean)
pivot1
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_6584\2740113143.py:1: FutureWarning: The provided callable <function mean at 0x000001F1BEFF8180> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot1 = pd.pivot_table(df, index = 'model_year' , aggfunc=np.mean)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# ...
